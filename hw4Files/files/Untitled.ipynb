# %%
import numpy as np

with open("globalIter0.csv") as f:
    x = int(f.readline().strip())
    y = int(f.readline().strip())
    ls = f.readline().strip().split(",")
    ls = [float(x) for x in ls[:-1]]
    ls = np.array(ls)
    ls = ls.reshape(x,y)
    ##plt.imshow(ls)
    X = np.arange(0,x,1)
    Y = np.arange(0,y,1)
    X,Y = np.meshgrid(X,Y)
    Z = ls

    fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
    surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)
    ax.set_zlim(-1.01, 1.01)

# %%
with open("globalIter1000.csv") as f:
    x = int(f.readline().strip())
    y = int(f.readline().strip())
    ls = f.readline().strip().split(",")
    ls = [float(x) for x in ls[:-1]]
    ls = np.array(ls)
    ls = ls.reshape(x,y)
    ##plt.imshow(ls)
    X = np.arange(0,x,1)
    Y = np.arange(0,y,1)
    X,Y = np.meshgrid(X,Y)
    Z = ls

    fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
    surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)
    ax.set_zlim(-1.01, 1.01)

# %%
with open("globalIter2000.csv") as f:
    x = int(f.readline().strip())
    y = int(f.readline().strip())
    ls = f.readline().strip().split(",")
    ls = [float(x) for x in ls[:-1]]
    ls = np.array(ls)
    ls = ls.reshape(x,y)
    ##plt.imshow(ls)
    X = np.arange(0,x,1)
    Y = np.arange(0,y,1)
    X,Y = np.meshgrid(X,Y)
    Z = ls

    fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
    surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)
    ax.set_zlim(-1.01, 1.01)
